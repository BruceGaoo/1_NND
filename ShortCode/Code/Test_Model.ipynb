# %%
import keras
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# Using TensorFlow backend.

# %%
model = keras.models.load_model('./result/model_16_8.h5')
L = pd.read_csv('./result/LOSS_16_8.csv')
# P_NN = pd.read_csv('./result/P_NN_16_4.csv')
# P_MAP = pd.read_csv('./result/P_MAP_16_4.csv')

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# modulator (Lambda)           (None, 16)                0
# _________________________________________________________________
# noise (Lambda)               (None, 16)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               2176
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_3 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_4 (Dense)              (None, 8)                 264
# ...
# Total params: 12,776
# Trainable params: 12,776
# Non-trainable params: 0
# _________________________________________________________________

# %%
plt.figure(figsize=(20,10))
plt.scatter(range(len(L['loss'])), L['loss'], s=0.01)

# %%
plt.figure(figsize=(10,7.5))
legend = ['NN FER', 'NN BER', 'MAP FER', 'MAP BER']

plt.plot(P_NN['ebn0'], P_NN['fer'], 'c') 
plt.plot(P_NN['ebn0'], P_NN['ber'], 'c--') 
plt.plot(P_MAP['ebn0_map'], P_MAP['fer_map'], 'r')
plt.plot(P_MAP['ebn0_map'], P_MAP['ber_map'], 'r--') 

plt.legend(legend, loc=3)
plt.yscale('log')
plt.xlabel('$E_b/N_0$')
plt.ylabel('FER / BER')    
plt.grid(True)
plt.show()
